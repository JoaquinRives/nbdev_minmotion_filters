# %%
# default_exp helpers

# %% [markdown]
# # module name here
#
# > API details.

# %%
#hide
from nbdev.showdoc import *

# %%
#export
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#export
def mock_signal(n=1000, minv=0, maxv=500, amplitud=20, noise=0):
    """ Generates a sinusoid signal."""
    signal = (amplitud/2)*np.sin(np.linspace(minv, maxv, n)/(2*np.pi))
    if noise > 0:
        signal = np.random.normal(0, noise, n) + signal
    return np.array(signal)

# %%
signal = mock_signal()

plt.plot(range(1000), signal); plt.show()

# %%
assert np.max(signal) < 10 and len(signal) == 1000
